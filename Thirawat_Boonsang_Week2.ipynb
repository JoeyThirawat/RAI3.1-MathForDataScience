# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ![Screenshot 2022-08-19 212956.png](data:image/png;base64,...)

# %%
a = np.array([[1,1],[3,2]])
b = np.array([-2,0])
x = np.linalg.solve(a,b)
print(x)
# Out:
# [ 4. -6.]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = np.array([[2,-25],[-1,15]])
b = np.array([17,-6])
x = np.linalg.solve(a,b)
print(x)
# Out:
# [21.  1.]

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Eq, Symbol, solve

x = Symbol('x')
# 48 - x = 10 (21 - x)
# 9x + 0y = 162

equation = Eq(x*(9), 162)
answer = str(int(solve(equation)[0]))

print(answer)
# Out:
# 18
