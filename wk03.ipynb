# %%
#Thirawat Boonsang 63011357

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importing the modules
import matplotlib.pyplot as plt
import numpy as np
 
# specifying the plot size
plt.figure(figsize = (10, 5))
 
# only one line may be specified; full height
plt.axvline(x = 7, color = 'b', label = 'axvline - full height')
 
# only one line may be specified; ymin & ymax specified as
# a percentage of y-range
plt.axvline(x = 7.25, ymin = 0.1, ymax = 0.90, color = 'r',
            label = 'axvline - % of full height')
 
# place legend outside
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')
 
# rendering plot
plt.show()

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Creating arrow
x_pos = 0
y_pos = 0
x_direct = 1
y_direct = 0
 
# Creating plot
fig, ax = plt.subplots(figsize = (10, 10))
ax.quiver(x_pos, y_pos, x_direct, y_direct)
 
# Show plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Creating arrow
x_pos = 3
y_pos = 4
x_direct = 5
y_direct = 2
 
# Creating plot
fig, ax = plt.subplots(figsize = (10, 10))
ax.quiver(0,0,5,5,color=['red'])

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# soa = np.array([[0, 0, 3, 2]])
# X, Y, U, V = zip(*soa)
#plt.figure()

ax = plt.gca()
ax.quiver(0, 0, 3, 2, angles='xy', scale_units='xy', scale=1, color=['red'])

# ax.set_xlim([-1, 5])
# ax.set_ylim([-1, 5])
ax.axis([-1,5,-1,5])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt




ax = plt.gca()
ax.quiver(0, 0, 3, 2, angles='xy', scale_units='xy', scale=1, color=['red'])

ax.axis([-1,5,-1,5])

plt.show()
