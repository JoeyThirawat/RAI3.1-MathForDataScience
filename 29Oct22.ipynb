# %%
import pandas as pd

# %%
# read dataset

df = pd.read_csv(r"C:\Users\thira\Documents\Math of data science\Transportation.csv")

# %%
df
# Out:
#      City ID  Number of weekly riders Price per week Population of city  \
# 0           1                 194,114            �38          3,192,047
# 1           2                  90,316           �106          4,724,700
# 2           3                 171,502            �98          1,447,566
# 3           4                 149,504            �22          2,469,989
# 4           5                 184,249            �56          6,289,179
# ..        ...                     ...            ...                ...
# 604       605                 107,751            �28          3,492,204
# 605       606                 176,232            �51          6,452,942
# 606       607                 143,169            �68          1,566,145
# 607       608                 158,906            �52          7,973,914
# 608       609                  90,723            �77          8,481,548
#
#     Monthly income of riders  Average parking rates per month  Year
# ...
