# %% [markdown]
# ### Thirawat Boonsang 63011357

# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# read dataset

df = pd.read_csv(r"C:\Users\thira\Documents\Math of data science\VDO.csv")

# %%
# display data

df
# Out:
#        Rank                  Video_Game Platform  Year     Genre  \
# 0       222                     FIFA 17      PS4  2016    Sports
# 1       272  Uncharted 4: A Thief's End      PS4  2016   Shooter
# 2       352   Tom Clancy's The Division      PS4  2016   Shooter
# 3       772             Far Cry: Primal      PS4  2016    Action
# 4       847   Tom Clancy's The Division     XOne  2016   Shooter
# ...     ...                         ...      ...   ...       ...
# 16318  2671                      Boxing     2600  1980  Fighting
# 16319  4027                  Ice Hockey     2600  1980    Sports
# 16320  5368                     Freeway     2600  1980    Action
# 16321  6319                      Bridge     2600  1980      Misc
# 16322  6898                    Checkers     2600  1980      Misc
#
#                          Publisher  North American Sales  EU Sales  \
# 0                  Electronic Arts                  0.28      3.75
# ...

# %%
df.head()   # the head() method displays the first several lines of a file.
# Out:
#    Rank                  Video_Game Platform  Year    Genre  \
# 0   222                     FIFA 17      PS4  2016   Sports
# 1   272  Uncharted 4: A Thief's End      PS4  2016  Shooter
# 2   352   Tom Clancy's The Division      PS4  2016  Shooter
# 3   772             Far Cry: Primal      PS4  2016   Action
# 4   847   Tom Clancy's The Division     XOne  2016  Shooter
#
#                      Publisher  North American Sales  EU Sales  Japan Sales  \
# 0              Electronic Arts                  0.28      3.75         0.06
# 1  Sony Computer Entertainment                  1.30      2.07         0.18
# 2                      Ubisoft                  1.28      1.61         0.15
# 3                      Ubisoft                  0.59      1.16         0.06
# 4                      Ubisoft                  1.20      0.62         0.00
#
#    Other Sales  World Sales
# 0         0.69         4.77
# 1         0.65         4.20
# 2         0.57         3.61
# 3         0.33         2.13
# ...

# %%
df.head(12)   # present the first "12" rows of df (data)
# Out:
#     Rank                  Video_Game Platform  Year         Genre  \
# 0    222                     FIFA 17      PS4  2016        Sports
# 1    272  Uncharted 4: A Thief's End      PS4  2016       Shooter
# 2    352   Tom Clancy's The Division      PS4  2016       Shooter
# 3    772             Far Cry: Primal      PS4  2016        Action
# 4    847   Tom Clancy's The Division     XOne  2016       Shooter
# 5   1028                   Overwatch      PS4  2016       Shooter
# 6   1158                No Man's Sky      PS4  2016        Action
# 7   1191              Dark Souls III      PS4  2016  Role-Playing
# 8   1226                     FIFA 17     XOne  2016        Sports
# 9   1391                 Doom (2016)      PS4  2016       Shooter
# 10  1570               Yokai Watch 3      3DS  2016        Action
# 11  1630               Madden NFL 17      PS4  2016        Sports
#
#                       Publisher  North American Sales  EU Sales  Japan Sales  \
# ...

# %%
#  use the type function to see what kind of df(data) is

type(df)   # it is a DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
# used an attribute called "dtypes" to present the kind of things
# that "df" data contain

df.dtypes
# Out:
# Rank                      int64
# Video_Game               object
# Platform                 object
# Year                      int64
# Genre                    object
# Publisher                object
# North American Sales    float64
# EU Sales                float64
# Japan Sales             float64
# Other Sales             float64
# World Sales             float64
# dtype: object

# %%
# used "colums" ot see lists of name indexes 

df.columns
# Out:
# Index(['Rank', 'Video_Game', 'Platform', 'Year', 'Genre', 'Publisher',
#        'North American Sales', 'EU Sales', 'Japan Sales', 'Other Sales',
#        'World Sales'],
#       dtype='object')

# %%
# used "shape" to see => 16323 rows × 11 columns

df.shape
# Out:
# (16323, 11)

# %%
df.tail(10)
# Out:
#        Rank             Video_Game Platform  Year     Genre   Publisher  \
# 16313  9497  RealSports Volleyball     2600  1981    Sports       Atari
# 16314   259              Asteroids     2600  1980   Shooter       Atari
# 16315   545        Missile Command     2600  1980   Shooter       Atari
# 16316  1768                Kaboom!     2600  1980      Misc  Activision
# 16317  1971               Defender     2600  1980      Misc       Atari
# 16318  2671                 Boxing     2600  1980  Fighting  Activision
# 16319  4027             Ice Hockey     2600  1980    Sports  Activision
# 16320  5368                Freeway     2600  1980    Action  Activision
# 16321  6319                 Bridge     2600  1980      Misc  Activision
# 16322  6898               Checkers     2600  1980      Misc       Atari
#
#        North American Sales  EU Sales  Japan Sales  Other Sales  World Sales
# 16313                  0.12      0.01          0.0         0.00         0.13
# ...

# %%
df.isnull().sum()
# Out:
# Rank                     0
# Video_Game               0
# Platform                 0
# Year                     0
# Genre                    0
# Publisher               36
# North American Sales     0
# EU Sales                 0
# Japan Sales              0
# Other Sales              0
# World Sales              0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Rank                     0
# Video_Game               0
# Platform                 0
# Year                     0
# Genre                    0
# Publisher               36
# North American Sales     0
# EU Sales                 0
# Japan Sales              0
# Other Sales              0
# World Sales              0
# dtype: int64

# %%
# drop missing data

df = df.dropna()

# %%
# find => max year

df['Year'].max()
# Out:
# 2016

# %%
# find => min year

df['Year'].min()
# Out:
# 1980

# %%
# sales in each continent

NA = df['North American Sales'].sum()
EU = df['EU Sales'].sum()
JP = df['Japan Sales'].sum()
oth = df['Other Sales'].sum()
sum = df['World Sales'].sum()

labels = 'North America', 'Europe', 'Japan', 'other'
sizes = [NA, EU, JP, oth]
plt.pie(sizes, labels=labels, autopct='%.2f')
plt.axis('equal')
plt.show()

# %%
# Japan aspect
genre_JP = df[["Genre", "Japan Sales"]]
genre_JP_sum = genre_JP.groupby(['Genre']).sum()
genre_JP_sum.plot(kind = 'pie', y ='Japan Sales', autopct='%.1f', figsize =(10, 10))
# Out:
# <AxesSubplot:ylabel='Japan Sales'>

# %%
# Europe aspect
genre_EU = df[["Genre", "EU Sales"]]
genre_EU_sum = genre_EU.groupby(['Genre']).sum()
genre_EU_sum.plot(kind = 'pie', y ='EU Sales', autopct='%.1f', figsize =(10, 10))
# Out:
# <AxesSubplot:ylabel='EU Sales'>

# %%
# north American aspect
genre_NA = df[["Genre", "North American Sales"]]
genre_NA_sum = genre_NA.groupby(['Genre']).sum()
genre_NA_sum.plot(kind = 'pie', y ='North American Sales', autopct='%.1f', figsize =(10, 10))
# Out:
# <AxesSubplot:ylabel='North American Sales'>

# %%
# other aspect
genre_other = df[["Genre", "Other Sales"]]
genre_other_sum = genre_other.groupby(['Genre']).sum()
genre_other_sum.plot(kind = 'pie', y ='Other Sales', autopct='%.1f', figsize =(10, 10))
# Out:
# <AxesSubplot:ylabel='Other Sales'>

# %%
# genre of game list

df['Genre'].value_counts()
# Out:
# Action          3250
# Sports          2304
# Misc            1686
# Role-Playing    1468
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       847
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x="Genre", data=df, order = df['Genre'].value_counts().index)
plt.xticks(rotation=90);

# %%
# the increasing of year that games has relased

plt.figure(figsize=(15, 10))
sns.countplot(x="Year", data=df, order = df.groupby(by=['Year'])['Video_Game'].count().sort_values(ascending=False).index)
plt.xticks(rotation=90);

# %%
# games sales values worldwide

data_year = df.groupby(by=['Year'])['World Sales'].sum()
data_year = data_year.reset_index()

plt.figure(figsize=(15, 10))
sns.barplot(x="Year", y="World Sales", data=data_year)
plt.xticks(rotation=90);

# %%
# sale price of each games' genre

data_genre = df.groupby(by=['Genre'])['World Sales'].sum()
data_genre = data_genre.reset_index()
data_genre = data_genre.sort_values(by=['World Sales'], ascending=False)

plt.figure(figsize=(15, 10))
sns.barplot(x="Genre", y="World Sales", data=data_genre)
plt.xticks(rotation=90);

# %%
# sale price of each platfrom

data_platform = df.groupby(by=['Platform'])['World Sales'].sum()
data_platform = data_platform.reset_index()
data_platform = data_platform.sort_values(by=['World Sales'], ascending=False)

plt.figure(figsize=(15, 10))
sns.barplot(x="Platform", y="World Sales", data=data_platform)
plt.xticks(rotation=90);

# %%
# sales compearison of each platforms

comp_platform = df[['Platform', 'North American Sales', 'EU Sales', 'Japan Sales', 'Other Sales']]
comp_platform.head()

comp_platform = comp_platform.groupby(by=['Platform']).sum().reset_index()

comp_table = pd.melt(comp_platform, id_vars=['Platform'], value_vars=[ 'North American Sales', 'EU Sales', 'Japan Sales', 'Other Sales'], var_name='Sale_Area', value_name='Sale_Price')
comp_table.head()

plt.figure(figsize=(30, 15))
sns.barplot(x='Platform', y='Sale_Price', hue='Sale_Area', data=comp_table)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %%
# list of publisher worldwide

sale_pbl = df[['Publisher', 'World Sales']]
sale_pbl = sale_pbl.groupby('Publisher')['World Sales'].sum().sort_values(ascending=False).head(20)
sale_pbl = pd.DataFrame(sale_pbl).reset_index()

plt.figure(figsize=(15, 10))
sns.barplot(x='Publisher', y='World Sales', data=sale_pbl)
plt.xticks(rotation=90);

# %%
# total revenue

top_sale_reg = df[['North American Sales', 'EU Sales', 'Japan Sales', 'Other Sales']]
top_sale_reg = top_sale_reg.sum().reset_index()
top_sale_reg = top_sale_reg.rename(columns={"index": "region", 0: "sale"})
top_sale_reg

plt.figure(figsize=(12, 8))
sns.barplot(x='region', y='sale', data = top_sale_reg);
